# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt


# Load the dataset from the URL

url = "https://data.wa.gov/api/views/rpr4-cgyd/rows.csv?accessType=DOWNLOAD"
title_registration_data = pd.read_csv(url)

# Inspect the dataset structure
title_registration_data.head()
# Out:
#       Clean Alternative Fuel Vehicle Type  VIN (1-10)  DOL Vehicle ID  \
# 0          Battery Electric Vehicle (BEV)  1N4BZ0CP3G       348273537
# 1          Battery Electric Vehicle (BEV)  5YJ3E1EB7K       244708467
# 2          Battery Electric Vehicle (BEV)  5YJ3E1EB7K       244708467
# 3          Battery Electric Vehicle (BEV)  1N4AZ1CPXK         4664348
# 4  Plug-in Hybrid Electric Vehicle (PHEV)  YV4H600A3P       227359303
#
#    Model Year    Make    Model Primary Use  Electric Range  Odometer Reading  \
# 0        2016  NISSAN     Leaf   Passenger            84.0             44004
# 1        2019   TESLA  Model 3   Passenger           220.0                 0
# 2        2019   TESLA  Model 3   Passenger           220.0                50
# 3        2019  NISSAN     Leaf   Passenger           150.0                 0
# 4        2023   VOLVO     XC90   Passenger            32.0                 0
#
#                         Odometer Reading Description  ...  \
# 0                                     Actual Mileage  ...
# 1  Odometer reading is not collected at time of r...  ...
# 2                                     Actual Mileage  ...
# 3  Odometer reading is not collected at time of r...  ...
# 4  Odometer reading is not collected at time of r...  ...
#
#   Meets 2019 HB 2042 Sale Price/Value Requirement  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    2019 HB 2042: Battery Range Requirement  \
# 0         Battery range requirement is met
# 1         Battery range requirement is met
# 2         Battery range requirement is met
# 3         Battery range requirement is met
# 4         Battery range requirement is met
#
#              2019 HB 2042: Purchase Date Requirement  \
# 0  This transaction type is not eligible for the ...
# 1  This transaction type is not eligible for the ...
# 2        Vehicle purchase was before August 01, 2019
# 3  This transaction type is not eligible for the ...
# 4  This transaction type is not eligible for the ...
#
#           2019 HB 2042: Sale Price/Value Requirement  \
# 0  This transaction type is not eligible for the ...
# 1  This transaction type is not eligible for the ...
# 2                         The sale price is too high
# 3  This transaction type is not eligible for the ...
# 4  This transaction type is not eligible for the ...
#
#   Electric Vehicle Fee Paid Transportation Electrification Fee Paid  \
# 0            Not Applicable                          Not Applicable
# 1                        No                                      No
# 2            Not Applicable                          Not Applicable
# 3                       Yes                                     Yes
# 4                       Yes                                     Yes
#
#    Hybrid Vehicle Electrification Fee Paid    2020 GEOID Legislative District  \
# 0                           Not Applicable  5.303195e+10                 24.0
# 1                                       No  5.303302e+10                 48.0
# 2                           Not Applicable  5.303302e+10                 48.0
# 3                                       No  5.303303e+10                  5.0
# 4                                       No  5.303303e+10                  5.0
#
#                                     Electric Utility
# 0  BONNEVILLE POWER ADMINISTRATION||PUGET SOUND E...
# 1      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 2      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 3      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 4      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
#
# [5 rows x 34 columns]

# %%
# Filter the dataset to only include rows where 'New or Used Vehicle' is 'New'
new_vehicles_data = title_registration_data[title_registration_data['New or Used Vehicle'] == 'New']

# Display the first few rows of the filtered data
new_vehicles_data.head()
# Out:
#        Clean Alternative Fuel Vehicle Type  VIN (1-10)  DOL Vehicle ID  \
# 1           Battery Electric Vehicle (BEV)  5YJ3E1EB7K       244708467
# 2           Battery Electric Vehicle (BEV)  5YJ3E1EB7K       244708467
# 6   Plug-in Hybrid Electric Vehicle (PHEV)  YV4H600A3P       227359303
# 13          Battery Electric Vehicle (BEV)  JN1AZ0CP6B       101926373
# 49          Battery Electric Vehicle (BEV)  JN1AZ0CP6B       101926373
#
#     Model Year    Make    Model Primary Use  Electric Range  Odometer Reading  \
# 1         2019   TESLA  Model 3   Passenger           220.0                 0
# 2         2019   TESLA  Model 3   Passenger           220.0                50
# 6         2023   VOLVO     XC90   Passenger            32.0                 0
# 13        2011  NISSAN     Leaf   Passenger            73.0                 5
# 49        2011  NISSAN     Leaf   Passenger            73.0                 5
#
#                          Odometer Reading Description  ...  \
# 1   Odometer reading is not collected at time of r...  ...
# 2                                      Actual Mileage  ...
# 6   Odometer reading is not collected at time of r...  ...
# 13                                     Actual Mileage  ...
# 49                                     Actual Mileage  ...
#
#    Meets 2019 HB 2042 Sale Price/Value Requirement  \
# 1                                            False
# 2                                            False
# 6                                            False
# 13                                           False
# 49                                           False
#
#     2019 HB 2042: Battery Range Requirement  \
# 1          Battery range requirement is met
# 2          Battery range requirement is met
# 6          Battery range requirement is met
# 13         Battery range requirement is met
# 49         Battery range requirement is met
#
#               2019 HB 2042: Purchase Date Requirement  \
# 1   This transaction type is not eligible for the ...
# 2         Vehicle purchase was before August 01, 2019
# 6   This transaction type is not eligible for the ...
# 13  This transaction type is not eligible for the ...
# 49        Vehicle purchase was before August 01, 2019
#
#            2019 HB 2042: Sale Price/Value Requirement  \
# 1   This transaction type is not eligible for the ...
# 2                          The sale price is too high
# 6   This transaction type is not eligible for the ...
# 13  This transaction type is not eligible for the ...
# 49                    The sale price is not available
#
#    Electric Vehicle Fee Paid Transportation Electrification Fee Paid  \
# 1                         No                                      No
# 2             Not Applicable                          Not Applicable
# 6                         No                                      No
# 13                        No                                     NaN
# 49            Not Applicable                                     NaN
#
#     Hybrid Vehicle Electrification Fee Paid    2020 GEOID  \
# 1                                        No  5.303302e+10
# 2                            Not Applicable  5.303302e+10
# 6                                        No  5.303303e+10
# 13                                      NaN  5.303301e+10
# 49                                      NaN  5.303301e+10
#
#    Legislative District                               Electric Utility
# 1                  48.0  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 2                  48.0  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 6                   5.0  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 13                 37.0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 49                 37.0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
#
# [5 rows x 34 columns]

# %%
# Select only the relevant columns
cleaned_data = new_vehicles_data[['VIN (1-10)', 'DOL Vehicle ID', 'Model Year', 'Make', 'Model', 
                                        'New or Used Vehicle', 'Sale Date', 'Transaction Type', 
                                        'Transaction Date', 'Year', 'County', 'City', 'Postal Code']]

# Remove duplicates based on the 'VIN (1-10)' column
cleaned_new_vehicles = cleaned_data.drop_duplicates(subset='VIN (1-10)', keep='first').reset_index()

# Save the cleaned data to a new CSV file
cleaned_new_vehicles.to_csv('cleaned_new_vehicle_data.csv', index=False)

# Display the first few rows of the cleaned dataset without duplicates
cleaned_new_vehicles
# Out:
#          index  VIN (1-10)  DOL Vehicle ID  Model Year       Make  \
# 0            1  5YJ3E1EB7K       244708467        2019      TESLA
# 1            6  YV4H600A3P       227359303        2023      VOLVO
# 2           13  JN1AZ0CP6B       101926373        2011     NISSAN
# 3           71  5YJYGDEE7M       176302234        2021      TESLA
# 4           74  1G1FY6S09P       261162457        2023  CHEVROLET
# ...        ...         ...             ...         ...        ...
# 11657  1167341  1G6RP1E42E       217801853        2014   CADILLAC
# 11658  1169409  5YJRE1A30A       158201522        2010      TESLA
# 11659  1169436  YH4K14AA2C       157201656        2012     FISKER
# 11660  1171112  7FCTGAAL4R       267084310        2024     RIVIAN
# 11661  1171419  3FMTK1S51R       270008147        2024       FORD
#
#                 Model New or Used Vehicle         Sale Date  \
# 0             Model 3                 New               NaN
# 1                XC90                 New               NaN
# 2                Leaf                 New  February 28 2011
# 3             Model Y                 New    August 28 2021
# 4            Bolt EUV                 New               NaN
# ...               ...                 ...               ...
# 11657             ELR                 New     April 26 2014
# 11658        Roadster                 New    August 20 2010
# 11659           Karma                 New     April 16 2012
# 11660             R1T                 New       May 09 2024
# 11661  Mustang Mach-E                 New    August 15 2024
#
#             Transaction Type   Transaction Date  Year     County        City  \
# 0      Original Registration   February 28 2019  2019       King    BELLEVUE
# 1      Original Registration   December 22 2022  2022       King    ISSAQUAH
# 2      Original Registration      April 19 2011  2011       King     SEATTLE
# 3             Original Title  September 21 2021  2021       King      RENTON
# 4      Original Registration    January 25 2024  2024       King     SEATTLE
# ...                      ...                ...   ...        ...         ...
# 11657         Original Title        May 05 2014  2014     Yakima       SELAH
# 11658         Original Title  September 29 2010  2010       King     SEATTLE
# 11659         Original Title        May 08 2012  2012       King    BELLEVUE
# 11660         Original Title       June 21 2024  2024  Snohomish     BOTHELL
# 11661         Original Title  September 03 2024  2024    Whatcom  BELLINGHAM
#
#        Postal Code
# 0          98007.0
# 1          98027.0
# 2          98134.0
# 3          98059.0
# 4          98125.0
# ...            ...
# 11657      98942.0
# 11658      98103.0
# 11659      98004.0
# 11660      98012.0
# 11661      98226.0
#
# [11662 rows x 14 columns]
